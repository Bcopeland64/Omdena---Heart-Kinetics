# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
from skimpy import skim

import torch.nn as nn
# Out:
# 2023-04-27 09:03:42.936197: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 09:03:45.361599: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-27 09:03:45.361643: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-27 09:03:50.895554: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 09:03:50.912595: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 09:03:50.912633: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
#Check torch version
import torch
torch.__version__
# Out:
# '1.12.1+cu102'

# %%
import xarray as xr
import json
from typing import Union
from pathlib import Path
import glob



def to_path(p: Union[str, Path]) -> Path:
    return p if isinstance(p, Path) else Path(p)

def find_records(path: str):
    search_path: str = f"{path}/**/signals/"
    all_paths = list(map(lambda x: str(to_path(x).parent), glob.glob(search_path, recursive=True)))
    return all_paths

class RecordReader():
    def __init__(self, path: Union[str, Path]):
        self.path = to_path(path)

    def load_signal(self, sig_name):
        return xr.open_zarr(self.path / "signals" / sig_name / "dataset")

    def load_signal_meta(self, sig_name):
        with open(self.path / "signals" / sig_name / "meta.json", "r") as meta:
            return json.load(meta)
    
    def load_metadata(self):
        with open(self.path / "meta.json", "r") as meta:
            return json.load(meta)

    def load_crf_metadata(self):
        with open(self.path / "crf.json", "r") as meta:
            return json.load(meta)

# %%
records = find_records(("./"))
print(records, flush=True)
# Out:
# ['Dataset1/MMC-HFrEF/KINO/Sub-EY/MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-MT/MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-WZ/MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux', 'Dataset1/MMC-HFrEF/KINO/Sub-YI/MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-MV/MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-RK/MMC-HFrEF_RK_kinoV1_20190506-142648_gwo4YOgXnIvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-YT/MMC-HFrEF_YT_kinoV1_20190603-145424_gwokar1wzTvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-UF/MMC-HFrEF_UF_kinoV1_20190624-145537_gwR5aOzoqIvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-PU/MMC-HFrEF_PU_kinoV1_20190211-154927_gwd4wQLYnsvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-QR/MMC-HFrEF_QR_kinoV1_20190812-145831_gwRaDplewcvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-WJ/MMC-HFrEF_WJ_kinoV1_20190520-145741_gwoa9Rdn8ivvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-WF/MMC-HFrEF_WF_kinoV1_20190311-152449_gwdkamm9qtvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-GC/MMC-HFrEF_GC_kinoV1_20191125-162438_gwXz0YbXwfvvIo', 'Dataset1/MMC-HFrEF/KINO/Sub-LV/MMC-HFrEF_LV_kinoV1_20190204-150427_1Wo92n7OwiOGux', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-GT/KINO-HFrEF-Brug_GT_kinoV1_20171117-143627_VzqBMOEW0SmBIn', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-IH/KINO-HFrEF-Brug_IH_kinoV1_20171124-160827_Vzqdv04rzImBIn', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-SN/KINO-HFrEF-Brug_SN_kinoV1_20190531-123621_AKoW4RgN5h6oIm', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-VY/KINO-HFrEF-Brug_VY_kinoV1_20180126-162547_7XwDeQW0xTPwul', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-QL/2/KINO-HFrEF-Brug_QL_2_20201016-134547_d1z0LWebzc0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-CC/KINO-HFrEF-Brug_CC_kinoV1_20180607-134435_k0RPMRD2KCbEiK', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-JU/2/KINO-HFrEF-Brug_JU_2_20211001-135106_d118w2MOrU0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-PG/2/KINO-HFrEF-Brug_PG_2_20201201-153927_d1oNxwaRKT0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-PG/2/KINO-HFrEF-Brug_PG_2_20201204-134754_d1onqBYV4I0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-FU/2/KINO-HFrEF-Brug_FU_2_20210504-144555_d1lrzVXVKi0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-PI/2/KINO-HFrEF-Brug_PI_2_20210205-105924_d18LeR7eWC0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-MS/KINO-HFrEF-Brug_MS_kinoV1_20180529-123848_k0RbvXWqzhbEiK', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-GV/2/KINO-HFrEF-Brug_GV_2_20201016-123749_d1z04rBe4t0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-PQ/KINO-HFrEF-Brug_PQ_kinoV1_20171003-094218_Q5gbarAYDCq1Fq', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-UJ/KINO-HFrEF-Brug_UJ_kinoV1_20180529-084358_k0RbRbyG0TbEiK', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-VP/2/KINO-HFrEF-Brug_VP_2_20201204-161040_d1onBbxrzi0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-BG/2/KINO-HFrEF-Brug_BG_2_20201016-133959_d1z0LrKnmH0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-BG/2/KINO-HFrEF-Brug_BG_2_20201016-134141_d1z0LyBX6C0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-CA/2/KINO-HFrEF-Brug_CA_2_20201210-095733_d1oaBw4AKi0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-BD/2/KINO-HFrEF-Brug_BD_2_20201204-092549_d1onYp4keT0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-BD/2/KINO-HFrEF-Brug_BD_2_20201204-092208_d1onYVd16I0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-YU/2/KINO-HFrEF-Brug_YU_2_20201120-144502_d1oywGX54i0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-YP/2/KINO-HFrEF-Brug_YP_2_20201023-132503_d1z5q7GxeS0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-KG/2/KINO-HFrEF-Brug_KG_2_20201014-084440_8KW6wPgpMulfk', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-HG/2/KINO-HFrEF-Brug_HG_2_20201016-134027_d1z0Ly8BrS0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-BZ/2/KINO-HFrEF-Brug_BZ_2_20210219-153712_d18vk9BOgh0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-TU/2/KINO-HFrEF-Brug_TU_2_20210201-145528_d18Xeld2zC0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-UB/2/KINO-HFrEF-Brug_UB_2_20201120-160539_d1oyd757zC0nf5', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-YB/2/KINO-HFrEF-Brug_YB_2_20210323-104113_lOlRK5dVEHR4HW', 'Dataset1/KINO-HFrEF-Brug/KINO/Sub-HA/KINO-HFrEF-Brug_HA_kin ...

# %%
data = {}
for r in records:
    reader = RecordReader(r)
    metadata = reader.load_metadata()
    scg_metadata = reader.load_signal_meta('scg-k')
    rsp_metadata = reader.load_signal_meta('rsp')
    crf_data = reader.load_crf_metadata()
    
    value = {
            'age': metadata['subject']['age']['value'],
            'sex' : metadata['subject']['sex'],
            'weight': metadata['subject']['weight']['value'],
            'height' : metadata['subject']['height']['value'],
            'subject_id' : crf_data['subject_id'],
            'study_id' : crf_data['study_id'],
            'hf_type' : crf_data['hf_type'],
            'sample_rate_scgk' : scg_metadata['sample_rate'],
            'nrg_lin_scgk' : reader.load_signal("scg-k").nrg.sel(motion="lin").to_pandas(),
            'nrg_rot_scgk' : reader.load_signal("scg-k").nrg.sel(motion="rot").to_pandas(),
            'pwr_lin_scgk': reader.load_signal("scg-k").pwr.sel(motion="lin").to_pandas(),
            'pwr_rot_scgk': reader.load_signal("scg-k").pwr.sel(motion="rot").to_pandas(),
            'sample_rate_rsp' : rsp_metadata['sample_rate'],
            'rsp': reader.load_signal("rsp").signal.to_pandas()
            }
    data[metadata['id']] = value

# %%
df = pd.DataFrame.from_dict(data, orient='index')

# %%
import numpy as np
from scipy.stats import skew, kurtosis
import pywt

def calculate_features(ts):
    mean = np.mean(ts)
    std = np.std(ts)
    median = np.median(ts)
    minimum = np.min(ts)
    maximum = np.max(ts)
    skewness = skew(ts)
    kurt = kurtosis(ts)
    rms = np.sqrt(np.mean(np.square(ts)))
    zero_crossings = np.sum(np.diff(np.sign(ts)) != 0)
    
    # Wavelet transformation
    wavelet = 'db4'
    coeffs = pywt.wavedec(ts, wavelet, level=4)
    
    # Calculate wavelet features
    wavelet_mean = np.mean(np.concatenate(coeffs))
    wavelet_std = np.std(np.concatenate(coeffs))
    wavelet_energy = np.sum(np.square(np.concatenate(coeffs)))
    
    return [mean, std, median, minimum, maximum, skewness, kurt, rms, zero_crossings, wavelet_mean, wavelet_std, wavelet_energy]

# Compute time series features for each subject
for subject_id, value in data.items():
    for feature in ['nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp']:
        ts = value[feature].values
        features = calculate_features(ts)
        
        # Store the computed features
        value[f"{feature}_mean"] = features[0]
        value[f"{feature}_std"] = features[1]
        value[f"{feature}_median"] = features[2]
        value[f"{feature}_min"] = features[3]
        value[f"{feature}_max"] = features[4]
        value[f"{feature}_skew"] = features[5]
        value[f"{feature}_kurt"] = features[6]
        value[f"{feature}_rms"] = features[7]
        value[f"{feature}_zero_crossings"] = features[8]
        value[f"{feature}_wavelet_mean"] = features[9]
        value[f"{feature}_wavelet_std"] = features[10]
        value[f"{feature}_wavelet_energy"] = features[11]

# Convert the dictionary to a DataFrame
df = pd.DataFrame.from_dict(data, orient='index')

# %%
df.dtypes
# Out:
# age                   float64
# sex                    object
# weight                float64
# height                float64
# subject_id             object
#                        ...
# rsp_rms               float64
# rsp_zero_crossings      int64
# rsp_wavelet_mean      float64
# rsp_wavelet_std       float64
# rsp_wavelet_energy    float64
# Length: 74, dtype: object

# %%
# Checking target
df.hf_type.value_counts()
# Out:
# NoHF       477
# UNKNOWN    282
# HFrEF       85
# HFpEF       27
# HFmEF       20
# Name: hf_type, dtype: int64

# %%
# Dropping the hf_type = UNKNOWN
df = df[df["hf_type"]!="UNKNOWN"]

# %%
# Check counts again
df.hf_type.value_counts()
# Out:
# NoHF     477
# HFrEF     85
# HFpEF     27
# HFmEF     20
# Name: hf_type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
# Encode the hf_type column as integer labels
encoder = LabelEncoder()
df['hf_type'] = encoder.fit_transform(df['hf_type'])

# %%
# Creating a function to code HFpEF and HFmEF into one category, NoHF second category, and HFrEF third
def convert(df):
    if df["hf_type"]==3:
        return 0
    elif df["hf_type"]==2:
        return 2
    else:
        return 1

# %%
df["hf_type"] = df.apply(lambda df: convert(df), axis=1)

# %%
from scipy.signal import periodogram
from scipy.stats import entropy

def spectral_entropy(pxx):
    psd_norm = pxx / np.sum(pxx)
    return entropy(psd_norm)

# Initialize a list to store the feature data
feature_data = []

# Iterate through the data dictionary
for key, value in data.items():
    # Calculate the periodogram for each time series
    freq_nrg_lin, pxx_nrg_lin = periodogram(value['nrg_lin_scgk'])
    freq_nrg_rot, pxx_nrg_rot = periodogram(value['nrg_rot_scgk'])
    freq_pwr_lin, pxx_pwr_lin = periodogram(value['pwr_lin_scgk'])
    freq_pwr_rot, pxx_pwr_rot = periodogram(value['pwr_rot_scgk'])
    freq_rsp, pxx_rsp = periodogram(value['rsp'])

    # Calculate the frequency-domain features for each time series
    features = {
        'record_id': key,
        'nrg_lin_mean_freq': np.mean(freq_nrg_lin),
        'nrg_lin_median_freq': np.median(freq_nrg_lin),
        'nrg_lin_peak_freq': freq_nrg_lin[np.argmax(pxx_nrg_lin)],
        'nrg_lin_spectral_entropy': spectral_entropy(pxx_nrg_lin),
        'nrg_rot_mean_freq': np.mean(freq_nrg_rot),
        'nrg_rot_median_freq': np.median(freq_nrg_rot),
        'nrg_rot_peak_freq': freq_nrg_rot[np.argmax(pxx_nrg_rot)],
        'nrg_rot_spectral_entropy': spectral_entropy(pxx_nrg_rot),
        'pwr_lin_mean_freq': np.mean(freq_pwr_lin),
        'pwr_lin_median_freq': np.median(freq_pwr_lin),
        'pwr_lin_peak_freq': freq_pwr_lin[np.argmax(pxx_pwr_lin)],
        'pwr_lin_spectral_entropy': spectral_entropy(pxx_pwr_lin),
        'pwr_rot_mean_freq': np.mean(freq_pwr_rot),
        'pwr_rot_median_freq': np.median(freq_pwr_rot),
        'pwr_rot_peak_freq': freq_pwr_rot[np.argmax(pxx_pwr_rot)],
        'pwr_rot_spectral_entropy': spectral_entropy(pxx_pwr_rot),
        'rsp_mean_freq': np.mean(freq_rsp),
        'rsp_median_freq': np.median(freq_rsp),
        'rsp_peak_freq': freq_rsp[np.argmax(pxx_rsp)],
        'rsp_spectral_entropy': spectral_entropy(pxx_rsp)
    }
    
    # Add the features to the feature_data list
    feature_data.append(features)

# Convert the feature_data list into a DataFrame
features_df = pd.DataFrame(feature_data)

# %%
features_df.head()
# Out:
#                                            record_id  nrg_lin_mean_freq  \
# 0  MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2t...           0.249979
# 1  MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEku...           0.249979
# 2  MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNf...           0.249979
# 3  MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvI...           0.249979
# 4  MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7ni...           0.249979
#
#    nrg_lin_median_freq  nrg_lin_peak_freq  nrg_lin_spectral_entropy  \
# 0             0.249979           0.015665                  6.260469
# 1             0.249979           0.004250                  6.283518
# 2             0.249979           0.000333                  6.286389
# 3             0.249979           0.005250                  5.876797
# 4             0.249979           0.005000                  5.689868
#
#    nrg_rot_mean_freq  nrg_rot_median_freq  nrg_rot_peak_freq  \
# 0           0.249979             0.249979           0.007666
# 1           0.249979             0.249979           0.000083
# 2           0.249979             0.249979           0.000333
# 3           0.249979             0.249979           0.005250
# 4           0.249979             0.249979           0.005000
#
#    nrg_rot_spectral_entropy  pwr_lin_mean_freq  ...  pwr_lin_peak_freq  \
# 0                  6.634803           0.249979  ...           0.068078
# 1                  6.887951           0.249979  ...           0.093409
# 2                  6.532926           0.249979  ...           0.073161
# 3                  5.585985           0.249979  ...           0.057662
# 4                  6.377936           0.249979  ...           0.054245
#
#    pwr_lin_spectral_entropy  pwr_rot_mean_freq  pwr_rot_median_freq  \
# 0                  6.445916           0.249979             0.249979
# 1                  7.049933           0.249979             0.249979
# 2                  6.598020           0.249979             0.249979
# 3                  6.085939           0.249979             0.249979
# 4                  6.333234           0.249979             0.249979
#
#    pwr_rot_peak_freq  pwr_rot_spectral_entropy  rsp_mean_freq  \
# 0           0.083160                  7.068857       0.249979
# 1           0.249979                  7.651671       0.249979
# 2           0.100492                  7.028616       0.249979
# 3           0.249979                  7.209044       0.249979
# 4           0.100825                  7.166193       0.249979
#
#    rsp_median_freq  rsp_peak_freq  rsp_spectral_entropy
# 0         0.249979       0.002000              2.482062
# 1         0.249979       0.000750              2.470310
# 2         0.249979       0.000750              2.971475
# 3         0.249979       0.001833              1.623179
# 4         0.249979       0.001417              2.004515
#
# [5 rows x 21 columns]

# %%
# Set the index of features_df to be the record_id
features_df.set_index('record_id', inplace=True)

# %%
# Join the main DataFrame with the features_df
combined_df = pd.merge(df, features_df, left_index=True, right_index=True)

# %%
combined_df.head()
# Out:
#                                                      age     sex  weight  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo  70.0    Male   106.0
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo  70.0    Male    77.0
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux  72.0  Female    60.0
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo  67.0    Male    78.0
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo  68.0    Male   106.0
#
#                                                     height subject_id  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo    1.87         EY
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo    1.76         MT
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux    1.66         WZ
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo    1.75         YI
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo    1.84         MV
#
#                                                      study_id  hf_type  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo  MMC-HFrEF        2
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo  MMC-HFrEF        2
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux  MMC-HFrEF        2
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo  MMC-HFrEF        2
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo  MMC-HFrEF        2
#
#                                                     sample_rate_scgk  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo               200
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo               200
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux               200
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo               200
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo               200
#
#                                                                                          nrg_lin_scgk  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo  time
# 0        8.143398e-41
# 5        2.974699e-...
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo  time
# 0        4.827842e-41
# 5        3.143857e-...
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux  time
# 0        1.008940e-39
# 5        4.981065e-...
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo  time
# 0        1.621356e-41
# 5        3.310214e-...
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo  time
# 0        4.274874e-42
# 5        3.747583e-...
#
#                                                                                          nrg_rot_scgk  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo  time
# 0        3.429861e-19
# 5        2.323705e-...
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo  time
# 0        3.722609e-19
# 5        1.496852e-...
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux  time
# 0        1.613923e-19
# 5        7.237731e-...
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo  time
# 0        1.505611e-19
# 5        6.988511e-...
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo  time
# 0        2.533075e-19
# 5        1.138278e-...
#
#                                                     ... pwr_lin_peak_freq  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo  ...          0.068078
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo  ...          0.093409
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux  ...          0.073161
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo  ...          0.057662
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo  ...          0.054245
#
#                                                    pwr_lin_spectral_entropy  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo                 6.445916
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo                 7.049933
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux                 6.598020
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo                 6.085939
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo                 6.333234
#
#                                                     pwr_rot_mean_freq  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo           0.249979
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo           0.249979
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux           0.249979
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo           0.249979
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo           0.249979
#
#                                                    pwr_rot_median_freq  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo            0.249979
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo            0.249979
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux            0.249979
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo            0.249979
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo            0.249979
#
#                                                     pwr_rot_peak_freq  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo           0.083160
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo           0.249979
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux           0.100492
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo           0.249979
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo           0.100825
#
#                                                     pwr_rot_spectral_entropy  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo                  7.068857
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo                  7.651671
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux                  7.028616
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo                  7.209044
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo                  7.166193
#
#                                                     rsp_mean_freq  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo       0.249979
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo       0.249979
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux       0.249979
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo       0.249979
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo       0.249979
#
#                                                     rsp_median_freq  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo         0.249979
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo         0.249979
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux         0.249979
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo         0.249979
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo         0.249979
#
#                                                     rsp_peak_freq  \
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo       0.002000
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo       0.000750
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux       0.000750
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo       0.001833
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo       0.001417
#
#                                                     rsp_spectral_entropy
# MMC-HFrEF_EY_kinoV1_20190107-153210_gwd5ar2K2tvvIo              2.482062
# MMC-HFrEF_MT_kinoV1_20191210-161556_gwX8ymbEkuvvIo              2.470310
# MMC-HFrEF_WZ_kinoV1_20190930-145749_1WdAWm9mNfOGux              2.971475
# MMC-HFrEF_YI_kinoV1_20190909-150010_gwkwwq1lvIvvIo              1.623179
# MMC-HFrEF_MV_kinoV1_20190103-124526_gwdW4mA7nivvIo              2.004515
#
# [5 rows x 94 columns]

# %%
combined_df.columns
# Out:
# Index(['age', 'sex', 'weight', 'height', 'subject_id', 'study_id', 'hf_type',
#        'sample_rate_scgk', 'nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk',
#        'pwr_rot_scgk', 'sample_rate_rsp', 'rsp', 'nrg_lin_scgk_mean',
#        'nrg_lin_scgk_std', 'nrg_lin_scgk_median', 'nrg_lin_scgk_min',
#        'nrg_lin_scgk_max', 'nrg_lin_scgk_skew', 'nrg_lin_scgk_kurt',
#        'nrg_lin_scgk_rms', 'nrg_lin_scgk_zero_crossings',
#        'nrg_lin_scgk_wavelet_mean', 'nrg_lin_scgk_wavelet_std',
#        'nrg_lin_scgk_wavelet_energy', 'nrg_rot_scgk_mean', 'nrg_rot_scgk_std',
#        'nrg_rot_scgk_median', 'nrg_rot_scgk_min', 'nrg_rot_scgk_max',
#        'nrg_rot_scgk_skew', 'nrg_rot_scgk_kurt', 'nrg_rot_scgk_rms',
#        'nrg_rot_scgk_zero_crossings', 'nrg_rot_scgk_wavelet_mean',
#        'nrg_rot_scgk_wavelet_std', 'nrg_rot_scgk_wavelet_energy',
#        'pwr_lin_scgk_mean', 'pwr_lin_scgk_std', 'pwr_lin_scgk_median',
#        'pwr_lin_scgk_min', 'pwr_lin_scgk_max', 'pwr_lin_scgk_skew',
#        'pwr_lin_scgk_kurt', 'pwr_lin_scgk_rms', 'pwr_lin_scgk_zero_crossings',
#        'pwr_lin_scgk_wavelet_mean', 'pwr_lin_scgk_wavelet_std',
#        'pwr_lin_scgk_wavelet_energy', 'pwr_rot_scgk_mean', 'pwr_rot_scgk_std',
#        'pwr_rot_scgk_median', 'pwr_rot_scgk_min', 'pwr_rot_scgk_max',
#        'pwr_rot_scgk_skew', 'pwr_rot_scgk_kurt', 'pwr_rot_scgk_rms',
#        'pwr_rot_scgk_zero_crossings', 'pwr_rot_scgk_wavelet_mean',
#        'pwr_rot_scgk_wavelet_std', 'pwr_rot_scgk_wavelet_energy', 'rsp_mean',
#        'rsp_std', 'rsp_median', 'rsp_min', 'rsp_max', 'rsp_skew', 'rsp_kurt',
#        'rsp_rms', 'rsp_zero_crossings', 'rsp_wavelet_mean', 'rsp_wavelet_std',
#        'rsp_wavelet_energy', 'nrg_lin_mean_freq', 'nrg_lin_median_freq',
#        'nrg_lin_peak_freq', 'nrg_lin_spectral_entropy', 'nrg_rot_mean_freq',
#        'nrg_rot_median_freq', 'nrg_rot_peak_freq', 'nrg_rot_spectral_entropy',
#        'pwr_lin_mean_freq', 'pwr_lin_median_freq', 'pwr_lin_peak_freq',
#        'pwr_lin_spectral_entropy', 'pwr_rot_mean_freq', 'pwr_rot_median_freq',
#        'pwr_rot_peak_freq', 'pwr_rot_spectral_entropy', 'rsp_mean_freq',
#        'rsp_median_freq', 'rsp_peak_freq', 'rsp_spectral_entropy'],
#       dtype='object')

# %%
print(combined_df.dtypes.head(50))
# Out:
# age                            float64
# sex                             object
# weight                         float64
# height                         float64
# subject_id                      object
# study_id                        object
# hf_type                          int64
# sample_rate_scgk                 int64
# nrg_lin_scgk                    object
# nrg_rot_scgk                    object
# pwr_lin_scgk                    object
# pwr_rot_scgk                    object
# sample_rate_rsp                  int64
# rsp                             object
# nrg_lin_scgk_mean              float64
# nrg_lin_scgk_std               float64
# nrg_lin_scgk_median            float64
# nrg_lin_scgk_min               float64
# nrg_lin_scgk_max               float64
# nrg_lin_scgk_skew              float64
# nrg_lin_scgk_kurt              float64
# nrg_lin_scgk_rms               float64
# nrg_lin_scgk_zero_crossings      int64
# nrg_lin_scgk_wavelet_mean      float64
# nrg_lin_scgk_wavelet_std       float64
# nrg_lin_scgk_wavelet_energy    float64
# nrg_rot_scgk_mean              float64
# nrg_rot_scgk_std               float64
# nrg_rot_scgk_median            float64
# nrg_rot_scgk_min               float64
# nrg_rot_scgk_max               float64
# nrg_rot_scgk_skew              float64
# nrg_rot_scgk_kurt              float64
# nrg_rot_scgk_rms               float64
# nrg_rot_scgk_zero_crossings      int64
# nrg_rot_scgk_wavelet_mean      float64
# nrg_rot_scgk_wavelet_std       float64
# nrg_rot_scgk_wavelet_energy    float64
# pwr_lin_scgk_mean              float64
# pwr_lin_scgk_std               float64
# pwr_lin_scgk_median            float64
# pwr_lin_scgk_min               float64
# pwr_lin_scgk_max               float64
# pwr_lin_scgk_skew              float64
# pwr_lin_scgk_kurt              float64
# pwr_lin_scgk_rms               float64
# pwr_lin_scgk_zero_crossings      int64
# pwr_lin_scgk_wavelet_mean      float64
# pwr_lin_scgk_wavelet_std       float64
# pwr_lin_scgk_wavelet_energy    float64
# dtype: object

# %%
combined_df.isna().sum()
# Out:
# age                         0
# sex                         0
# weight                      0
# height                      0
# subject_id                  0
#                            ..
# pwr_rot_spectral_entropy    0
# rsp_mean_freq               0
# rsp_median_freq             0
# rsp_peak_freq               0
# rsp_spectral_entropy        0
# Length: 94, dtype: int64

# %%
combined_df.shape
# Out:
# (609, 94)

# %%
#prepare data for modeling
combined_df.drop(columns=['nrg_lin_scgk', 'nrg_rot_scgk', 'pwr_lin_scgk', 'pwr_rot_scgk', 'rsp'], inplace=True)
skim(combined_df)
# Out:
# ╭───────────────────────────────────── skimpy summary ──────────────────────────────────────╮
# │          Data Summary                Data Types                                           │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                    │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                    │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                    │
# │ │ Number of rows    │ 609    │ │ float64     │ 78    │                                    │
# │ │ Number of columns │ 89     │ │ int64       │ 8     │                                    │
# │ └───────────────────┴────────┘ │ object      │ 3     │                                    │
# │                                └─────────────┴───────┘                                    │
# │                                          number                                           │
# │ ┏━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━┓  │
# │ ┃        ┃ missin ┃ comple ┃ mean   ┃ sd     ┃ p0    ┃ p25    ┃ p75   ┃ p100   ┃ hist  ┃  │
# │ ┃        ┃ g      ┃ te     ┃        ┃        ┃       ┃        ┃       ┃        ┃       ┃  │
# │ ┃        ┃        ┃ rate   ┃        ┃        ┃       ┃        ┃       ┃        ┃       ┃  │
# │ ┡━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━┩  │
# │ │ age    │      0 │      1 │     44 │     19 │    17 │     27 │    60 │     97 │ █▃▄▅▂ │  │
# │ │ weight │      0 │      1 │     75 │     14 │    42 │     66 │    82 │    140 │ ▂█▅▂  │  │
# │ │ height │      0 │      1 │    1.7 │   0.58 │   1.5 │    1.6 │   1.8 │     16 │   █   │  │
# │ │ hf_typ │      0 │      1 │   0.36 │   0.71 │     0 │      0 │     0 │      2 │ █  ▁  │  │
# │ │ e      │        │        │        │        │       │        │       │        │   ▁   │  │
# │ │ sample │      0 │      1 │    220 │     40 │   200 │    200 │   250 │    500 │  █▃   │  │
# │ │ _rate_ │        │        │        │        │       │        │       │        │       │  │
# │ │ scgk   │        │        │        │        │       │        │       │        │       │  │
# │ │ sample │      0 │      1 │    220 │     40 │   200 │    200 │   250 │    500 │  █▃   │  │
# │ │ _rate_ │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp    │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 3.6e-0 │ 6.6e-0 │ 5.6e- │ 6.5e-0 │ 3.4e- │ 8.7e-0 │   █   │  │
# │ │ n_scgk │        │        │      7 │      7 │    09 │      8 │    07 │      6 │       │  │
# │ │ _mean  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 5.1e-0 │ 9.4e-0 │ 6.8e- │ 9.3e-0 │ 5.9e- │ 6.9e-0 │  █▁   │  │
# │ │ n_scgk │        │        │      6 │      6 │    09 │      8 │    06 │      5 │       │  │
# │ │ _std   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 4.5e-0 │ 4.8e-0 │ 2.6e- │ 2.4e-0 │ 5.2e- │ 8.7e-0 │   █   │  │
# │ │ n_scgk │        │        │      8 │      8 │    09 │      8 │    08 │      7 │       │  │
# │ │ _media │        │        │        │        │       │        │       │        │       │  │
# │ │ n      │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 4.6e-3 │ 1.5e-3 │ 3.7e- │ 3.4e-4 │ 8.8e- │  2e-35 │   █   │  │
# │ │ n_scgk │        │        │      7 │      6 │    43 │      1 │    38 │        │       │  │
# │ │ _min   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 0.0002 │ 0.0003 │ 7.2e- │ 1.1e-0 │ 0.000 │ 0.0019 │  █▁   │  │
# │ │ n_scgk │        │        │        │      5 │    08 │      6 │    26 │        │       │  │
# │ │ _max   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │     17 │     15 │   1.4 │    3.2 │    33 │     43 │ █▂▁▁▄ │  │
# │ │ n_scgk │        │        │        │        │       │        │       │        │   ▂   │  │
# │ │ _skew  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │    580 │    660 │   2.1 │     15 │  1200 │   2100 │  █▁   │  │
# │ │ n_scgk │        │        │        │        │       │        │       │        │  ▃▁▁  │  │
# │ │ _kurt  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 5.1e-0 │ 9.5e-0 │ 9.9e- │ 1.1e-0 │ 5.9e- │ 6.9e-0 │  █▁   │  │
# │ │ n_scgk │        │        │      6 │      6 │    09 │      7 │    06 │      5 │       │  │
# │ │ _rms   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │      0 │      0 │     0 │      0 │     0 │      0 │    █  │  │
# │ │ n_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _zero_ │        │        │        │        │       │        │       │        │       │  │
# │ │ cr     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 1.8e-0 │ 2.5e-0 │ 1.4e- │ 1.6e-0 │ 2.8e- │ 1.9e-0 │  █▂   │  │
# │ │ n_scgk │        │        │      7 │      7 │    09 │      8 │    07 │      6 │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 7.8e-0 │ 1.2e-0 │ 9.7e- │ 1.1e-0 │ 1.2e- │ 6.9e-0 │  █▄   │  │
# │ │ n_scgk │        │        │      6 │      5 │    09 │      7 │    05 │      5 │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 2.4e-0 │ 6.7e-0 │ 1.2e- │ 1.7e-1 │ 2.2e- │ 5.7e-0 │   █   │  │
# │ │ n_scgk │        │        │      6 │      6 │    12 │        │    06 │      5 │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │ 3.9e-0 │ 7.7e-0 │ 5e-11 │ 4.9e-0 │ 6.8e- │ 1.6e-0 │   █   │  │
# │ │ t_scgk │        │        │      8 │      8 │       │      9 │    08 │      6 │       │  │
# │ │ _mean  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │  1e-06 │ 1.9e-0 │ 4.5e- │ 9.5e-0 │ 2.4e- │ 2.8e-0 │  █▁   │  │
# │ │ t_scgk │        │        │        │      6 │    11 │      9 │    06 │      5 │       │  │
# │ │ _std   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │ 3.5e-0 │ 3.8e-0 │ 3.4e- │ 1.2e-0 │ 4.2e- │ 4.1e-0 │  █▁   │  │
# │ │ t_scgk │        │        │      9 │      9 │    11 │      9 │    09 │      8 │       │  │
# │ │ _media │        │        │        │        │       │        │       │        │       │  │
# │ │ n      │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │ 5.7e-1 │ 1.3e-1 │ 1.1e- │ 3.1e-1 │ 3e-18 │ 1.1e-1 │  █▁▁  │  │
# │ │ t_scgk │        │        │      8 │      7 │    23 │      9 │       │      6 │       │  │
# │ │ _min   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │ 5.7e-0 │ 0.0001 │ 6.3e- │ 1.2e-0 │ 0.000 │  0.001 │  █▁   │  │
# │ │ t_scgk │        │        │      5 │        │     1 │      7 │    13 │        │       │  │
# │ │ _max   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │     20 │     20 │   1.1 │    4.2 │    43 │    110 │ █▁▃▁  │  │
# │ │ t_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _skew  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │    900 │   1400 │     1 │     24 │  1900 │  14000 │  █▁   │  │
# │ │ t_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _kurt  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │  1e-06 │ 1.9e-0 │ 6.8e- │ 1.1e-0 │ 2.4e- │ 2.8e-0 │  █▁   │  │
# │ │ t_scgk │        │        │        │      6 │    11 │      8 │    06 │      5 │       │  │
# │ │ _rms   │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │      0 │      0 │     0 │      0 │     0 │      0 │    █  │  │
# │ │ t_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _zero_ │        │        │        │        │       │        │       │        │       │  │
# │ │ cr     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │ 4.6e-0 │ 7.6e-0 │ 1.4e- │ 1.3e-0 │ 5.7e- │ 4.8e-0 │ █▂ ▁  │  │
# │ │ t_scgk │        │        │      8 │      8 │    11 │      9 │    08 │      7 │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │ 2.2e-0 │ 3.8e-0 │ 6.6e- │ 1.1e-0 │ 3.7e- │ 2.8e-0 │  █▂▁  │  │
# │ │ t_scgk │        │        │      6 │      6 │    11 │      8 │    06 │      5 │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │ 2.6e-0 │ 7.2e-0 │ 5.5e- │ 1.4e-1 │ 1.6e- │ 9.6e-0 │   █   │  │
# │ │ t_scgk │        │        │      7 │      7 │    17 │      2 │    07 │      6 │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ -1.2e- │  2e-05 │ -0.00 │ -3.2e- │ 7.2e- │ 4.4e-0 │   ▂▁█ │  │
# │ │ n_scgk │        │        │     05 │        │   012 │     05 │     1 │      5 │       │  │
# │ │ _mean  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ 0.0005 │ 0.0007 │ 3.8e- │ 5.4e-0 │ 0.001 │ 0.0047 │  █▄▁  │  │
# │ │ n_scgk │        │        │      5 │      3 │    07 │      6 │       │        │       │  │
# │ │ _std   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ -3.9e- │ 5.8e-0 │ -5.5e │ -2.1e- │ 1.4e- │ 2.3e-0 │    ▁█ │  │
# │ │ n_scgk │        │        │     09 │      8 │   -07 │     08 │    08 │      7 │       │  │
# │ │ _media │        │        │        │        │       │        │       │        │       │  │
# │ │ n      │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ -0.024 │   0.03 │ -0.11 │ -0.054 │ -5.1e │ -2.7e- │   ▃▂  │  │
# │ │ n_scgk │        │        │        │        │       │        │   -05 │     06 │   █   │  │
# │ │ _min   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ 0.0079 │   0.02 │ 2.8e- │ 5.2e-0 │ 0.000 │   0.14 │  █▁   │  │
# │ │ n_scgk │        │        │        │        │    06 │      5 │    51 │        │       │  │
# │ │ _max   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │    -11 │     17 │   -42 │    -34 │  0.19 │     22 │ ▅  █▃ │  │
# │ │ n_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _skew  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │    630 │    730 │   1.4 │     14 │  1300 │   2600 │ █▁▂▁▂ │  │
# │ │ n_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _kurt  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ 0.0005 │ 0.0007 │ 3.8e- │ 5.4e-0 │ 0.001 │ 0.0047 │  █▄▁  │  │
# │ │ n_scgk │        │        │      5 │      3 │    07 │      6 │       │        │       │  │
# │ │ _rms   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │   2000 │   1800 │   570 │   1700 │  2000 │  20000 │   █   │  │
# │ │ n_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _zero_ │        │        │        │        │       │        │       │        │       │  │
# │ │ cr     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ -1.5e- │ 2.8e-0 │ -0.00 │ -4.5e- │ -1e-0 │ 3.2e-0 │   ▂▂▁ │  │
# │ │ n_scgk │        │        │     05 │      5 │   016 │     05 │     9 │      5 │   █   │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │ 0.0009 │ 0.0012 │ 3.8e- │ 5.4e-0 │ 0.002 │ 0.0047 │ █▁▂▂  │  │
# │ │ n_scgk │        │        │      5 │        │    07 │      6 │     3 │        │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │  0.029 │   0.04 │ 1.8e- │ 3.7e-0 │ 0.079 │   0.27 │  █▄   │  │
# │ │ n_scgk │        │        │        │        │    09 │      7 │       │        │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ -2.3e- │ 4.7e-0 │ -2.1e │ -2.6e- │ 1.9e- │ 8.6e-0 │  ▁▂ █ │  │
# │ │ t_scgk │        │        │     06 │      6 │   -05 │     06 │    11 │      6 │       │  │
# │ │ _mean  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ 0.0001 │ 0.0002 │ 5e-09 │ 7.3e-0 │ 0.000 │ 0.0014 │ █▂ ▁  │  │
# │ │ t_scgk │        │        │      3 │      2 │       │      7 │    27 │        │       │  │
# │ │ _std   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ -1.5e- │ 4.7e-0 │ -3.9e │ -2.7e- │ 2e-11 │ 2.1e-0 │    █▁ │  │
# │ │ t_scgk │        │        │     09 │      9 │   -08 │     09 │       │      8 │       │  │
# │ │ _media │        │        │        │        │       │        │       │        │       │  │
# │ │ n      │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ -0.007 │  0.013 │ -0.05 │ -0.014 │ -8.2e │ -5.4e- │   ▁   │  │
# │ │ t_scgk │        │        │      1 │        │     3 │        │   -06 │     08 │  ▁▁█  │  │
# │ │ _min   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ 0.0014 │ 0.0055 │ 5.7e- │  8e-06 │ 0.000 │  0.052 │   █   │  │
# │ │ t_scgk │        │        │        │        │    08 │        │    66 │        │       │  │
# │ │ _max   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │    -11 │     25 │   -59 │    -42 │  0.29 │     56 │ ▃ ▁█  │  │
# │ │ t_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _skew  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │    970 │   1700 │   1.8 │     20 │  2000 │  24000 │   █   │  │
# │ │ t_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _kurt  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ 0.0001 │ 0.0002 │ 5e-09 │ 7.3e-0 │ 0.000 │ 0.0014 │ █▂ ▁  │  │
# │ │ t_scgk │        │        │      3 │      2 │       │      7 │    27 │        │       │  │
# │ │ _rms   │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │   3100 │   4100 │   760 │   2500 │  2900 │  46000 │   █   │  │
# │ │ t_scgk │        │        │        │        │       │        │       │        │       │  │
# │ │ _zero_ │        │        │        │        │       │        │       │        │       │  │
# │ │ cr     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ -2.2e- │ 4.3e-0 │ -1.6e │ -4.1e- │ 3.9e- │ 1.5e-0 │ ▁▂▁█  │  │
# │ │ t_scgk │        │        │     06 │      6 │   -05 │     06 │    08 │      5 │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ 0.0001 │ 0.0003 │ 5.1e- │ 7.3e-0 │ 0.000 │ 0.0014 │  █▂▁  │  │
# │ │ t_scgk │        │        │      8 │      2 │    09 │      7 │    37 │        │       │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │ 0.0019 │ 0.0051 │ 3.1e- │ 6.8e-0 │ 0.001 │  0.025 │   █   │  │
# │ │ t_scgk │        │        │        │        │    13 │      9 │     9 │        │   ▁   │  │
# │ │ _wavel │        │        │        │        │       │        │       │        │       │  │
# │ │ et     │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_me │      0 │      1 │ -0.018 │  0.059 │ -0.21 │  -0.05 │ 0.009 │   0.22 │  ▂█▃  │  │
# │ │ an     │        │        │        │        │       │        │     5 │        │       │  │
# │ │ rsp_st │      0 │      1 │   0.78 │   0.57 │  0.28 │   0.59 │  0.81 │     12 │   █   │  │
# │ │ d      │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_me │      0 │      1 │ 0.0001 │  0.025 │  -0.2 │ -9.7e- │ 1.1e- │   0.11 │    █▂ │  │
# │ │ dian   │        │        │      1 │        │       │     18 │    17 │        │       │  │
# │ │ rsp_mi │      0 │      1 │   -2.4 │    7.9 │  -190 │   -2.3 │  -1.3 │  -0.71 │       │  │
# │ │ n      │        │        │        │        │       │        │       │        │   █   │  │
# │ │ rsp_ma │      0 │      1 │    2.1 │    3.2 │  0.63 │    1.1 │   2.1 │     68 │   █   │  │
# │ │ x      │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_sk │      0 │      1 │ -0.098 │   0.52 │  -7.6 │  -0.27 │ 0.063 │    2.3 │     █ │  │
# │ │ ew     │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_ku │      0 │      1 │   0.42 │    5.6 │  -1.5 │     -1 │  0.34 │    120 │   █   │  │
# │ │ rt     │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_rm │      0 │      1 │   0.78 │   0.57 │  0.28 │   0.59 │  0.81 │     12 │   █   │  │
# │ │ s      │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_ze │      0 │      1 │     32 │     30 │     9 │     22 │    34 │    350 │   █   │  │
# │ │ ro_cro │        │        │        │        │       │        │       │        │       │  │
# │ │ ssings │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_wa │      0 │      1 │ -0.004 │  0.015 │ -0.05 │ -0.013 │ 0.002 │  0.056 │  ▂█▃  │  │
# │ │ velet_ │        │        │      5 │        │     2 │        │     3 │        │       │  │
# │ │ mean   │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_wa │      0 │      1 │   0.78 │   0.57 │  0.28 │   0.59 │  0.81 │     12 │   █   │  │
# │ │ velet_ │        │        │        │        │       │        │       │        │       │  │
# │ │ std    │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_wa │      0 │      1 │  55000 │ 110000 │  1200 │   4200 │  8000 │ 260000 │   █   │  │
# │ │ velet_ │        │        │        │      0 │       │        │       │     00 │       │  │
# │ │ energy │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ n_mean │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ n_medi │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ an_fre │        │        │        │        │       │        │       │        │       │  │
# │ │ q      │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │ 0.0026 │ 0.0029 │ 4.8e- │ 0.0001 │ 0.005 │  0.016 │  █▂▃  │  │
# │ │ n_peak │        │        │        │        │    06 │      7 │     3 │        │       │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_li │      0 │      1 │    6.3 │   0.65 │   4.1 │    5.8 │   6.7 │    8.1 │  ▂██▅ │  │
# │ │ n_spec │        │        │        │        │       │        │       │        │       │  │
# │ │ tral_e │        │        │        │        │       │        │       │        │       │  │
# │ │ nt     │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ t_mean │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ t_medi │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ an_fre │        │        │        │        │       │        │       │        │       │  │
# │ │ q      │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │  0.004 │   0.01 │ 4e-06 │ 0.0002 │ 0.006 │   0.25 │   █   │  │
# │ │ t_peak │        │        │        │        │       │      9 │       │        │       │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ nrg_ro │      0 │      1 │    6.7 │   0.59 │   4.9 │    6.3 │   7.1 │    9.3 │  ▅█▃  │  │
# │ │ t_spec │        │        │        │        │       │        │       │        │       │  │
# │ │ tral_e │        │        │        │        │       │        │       │        │       │  │
# │ │ nt     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ n_mean │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ n_medi │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ an_fre │        │        │        │        │       │        │       │        │       │  │
# │ │ q      │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │  0.051 │   0.04 │ 6.7e- │ 0.0002 │ 0.074 │   0.14 │ ▇▁█▃▁ │  │
# │ │ n_peak │        │        │        │        │    05 │        │       │        │   ▂   │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_li │      0 │      1 │    6.8 │   0.43 │   5.1 │    6.6 │   7.1 │    9.3 │  ▂█▁  │  │
# │ │ n_spec │        │        │        │        │       │        │       │        │       │  │
# │ │ tral_e │        │        │        │        │       │        │       │        │       │  │
# │ │ nt     │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ t_mean │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ t_medi │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ an_fre │        │        │        │        │       │        │       │        │       │  │
# │ │ q      │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │   0.11 │  0.092 │ 6.7e- │ 0.0016 │  0.17 │   0.25 │ █▅█▃  │  │
# │ │ t_peak │        │        │        │        │    05 │        │       │        │   █   │  │
# │ │ _freq  │        │        │        │        │       │        │       │        │       │  │
# │ │ pwr_ro │      0 │      1 │    7.3 │    0.4 │   5.8 │    7.1 │   7.4 │     10 │   █▄  │  │
# │ │ t_spec │        │        │        │        │       │        │       │        │       │  │
# │ │ tral_e │        │        │        │        │       │        │       │        │       │  │
# │ │ nt     │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_me │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ an_fre │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ q      │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_me │      0 │      1 │   0.25 │ 9.9e-0 │  0.25 │   0.25 │  0.25 │   0.25 │  ▅▂   │  │
# │ │ dian_f │        │        │        │      6 │       │        │       │        │   █   │  │
# │ │ req    │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_pe │      0 │      1 │ 0.0011 │ 0.0003 │ 0.000 │ 0.0008 │ 0.001 │ 0.0022 │ ▁█▃▃▁ │  │
# │ │ ak_fre │        │        │        │      4 │    31 │      3 │     3 │        │       │  │
# │ │ q      │        │        │        │        │       │        │       │        │       │  │
# │ │ rsp_sp │      0 │      1 │      2 │   0.73 │  0.56 │    1.4 │   2.5 │    4.8 │ ▅▆█▄  │  │
# │ │ ectral │        │        │        │        │       │        │       │        │       │  │
# │ │ _entro │        │        │        │        │       │        │       │        │       │  │
# │ │ py     │        │        │        │        │       │        │       │        │       │  │
# │ └────────┴────────┴────────┴────────┴────────┴───────┴────────┴───────┴────────┴───────┘  │
# ╰─────────────────────────────────────────── End ───────────────────────────────────────────╯

# %%
#separate each signal
nrg_signal = combined_df[['nrg_lin_mean_freq', 'nrg_lin_median_freq', 'nrg_lin_peak_freq', 'nrg_lin_spectral_entropy', 'nrg_rot_mean_freq', 'nrg_rot_median_freq', 'nrg_rot_peak_freq', 'nrg_rot_spectral_entropy']]
rot_signal = combined_df[['pwr_lin_mean_freq', 'pwr_lin_median_freq', 'pwr_lin_peak_freq', 'pwr_lin_spectral_entropy', 'pwr_rot_mean_freq', 'pwr_rot_median_freq', 'pwr_rot_peak_freq', 'pwr_rot_spectral_entropy']]
pwr_signal = combined_df[['rsp_mean_freq', 'rsp_median_freq', 'rsp_peak_freq', 'rsp_spectral_entropy']]

# %%
print(nrg_signal.shape)
print(rot_signal.shape)
print(pwr_signal.shape)
# Out:
# (609, 8)
# (609, 8)
# (609, 4)

# %%
nrg_signal.columns
# Out:
# Index(['nrg_lin_mean_freq', 'nrg_lin_median_freq', 'nrg_lin_peak_freq',
#        'nrg_lin_spectral_entropy', 'nrg_rot_mean_freq', 'nrg_rot_median_freq',
#        'nrg_rot_peak_freq', 'nrg_rot_spectral_entropy'],
#       dtype='object')

# %% [markdown]
# <h1>Pytorch Neural Network with Skortch Integration w/PyCaret Tuning</h1>

# %%
#PyTorch Neural Network

import torch.nn as nn
class Net(nn.Module):
    def __init__(self, num_inputs=12, num_units_d1=200, num_units_d2=100):
        super(Net, self).__init__()
        self.dense0 = nn.Linear(num_inputs, num_units_d1)
        self.nonlin = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.dense1 = nn.Linear(num_units_d1, num_units_d2)
        self.output = nn.Linear(num_units_d2, 2)
        self.softmax = nn.Softmax(dim=-1)
    def forward(self, X, **kwargs):
        X = self.nonlin(self.dense0(X))
        X = self.dropout(X)
        X = self.nonlin(self.dense1(X))
        X = self.softmax(self.output(X))
        return X

# %%
#Skortch Neural Network
from skorch import NeuralNetClassifier
net = NeuralNetClassifier(
    module=Net,
    max_epochs=30,
    lr=0.1,
    batch_size=32,
    train_split=None
)

# %%
#TabNet Classifier
# !pip install pytorch-tabnet --quiet

import torch
import numpy as np
from skorch import NeuralNetClassifier
from skorch.callbacks import EarlyStopping
from pytorch_tabnet.tab_model import TabNetClassifier
from torch.optim.lr_scheduler import ReduceLROnPlateau


# Define the TabNet model
tabnet = TabNetClassifier(
    n_d=8, n_a=8, n_steps=3, gamma=1.3, lambda_sparse=0.001,
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=2e-2, weight_decay=1e-5),
    mask_type='entmax',
    scheduler_params=dict(mode='min', patience=5, min_lr=1e-5, factor=0.5),
    scheduler_fn=torch.optim.lr_scheduler.ReduceLROnPlateau,
)


# Define the Skorch neural network classifier
neural = NeuralNetClassifier(
    tabnet,
    max_epochs=100,
    batch_size=256,
    optimizer=torch.optim.Adam,
    optimizer__lr=1e-2,
    optimizer__weight_decay=1e-5,
    criterion=torch.nn.CrossEntropyLoss,
    callbacks=[EarlyStopping(patience=10)],
    train_split=None,
    callbacks__scheduler=ReduceLROnPlateau,
    callbacks__scheduler__mode='min',
    callbacks__scheduler__patience=5,
    callbacks__scheduler__factor=0.5,
)
# Out:
# WARNING: Ignoring invalid distribution -andas (/home/brandon/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -andas (/home/brandon/anaconda3/lib/python3.9/site-packages)
# /home/brandon/anaconda3/lib/python3.9/site-packages/pytorch_tabnet/abstract_model.py:75: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %%
#1D CNN
import numpy as np
from sklearn.datasets import make_classification
from skorch import NeuralNetClassifier
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# Define the 1D CNN model
class CNN1D(nn.Module):
    def __init__(self, input_size, num_classes):
        super(CNN1D, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=input_size, out_channels=32, kernel_size=3)
        self.pool1 = nn.MaxPool1d(kernel_size=2)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3)
        self.pool2 = nn.MaxPool1d(kernel_size=2)
        self.conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3)
        self.pool3 = nn.MaxPool1d(kernel_size=2)
        self.fc1 = nn.Linear(in_features=128 * 12, out_features=512)
        self.fc2 = nn.Linear(in_features=512, out_features=num_classes)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.pool3(x)
        x = x.view(-1, 128 * 12)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Set the hyperparameters
input_size = 10 # Number of input features
num_classes = 2 # Number of output classes
learning_rate = 0.001
batch_size = 32
num_epochs = 100

# Define the PyTorch neural network classifier
One_CNN = NeuralNetClassifier(
    CNN1D(input_size, num_classes),
    criterion=nn.CrossEntropyLoss,
    optimizer=optim.Adam,
    lr=learning_rate,
    batch_size=batch_size,
    max_epochs=num_epochs,
    device='cuda' if torch.cuda.is_available() else 'cpu',
    callbacks=[
        ('early_stop', EarlyStopping(monitor='valid_loss', patience=5))
    ]
)

# %%
import numpy as np
from sklearn.datasets import make_classification
from skorch import NeuralNetClassifier
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# Define the 2D CNN model
class CNN2D(nn.Module):
    def __init__(self, input_shape, num_classes):
        super(CNN2D, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=input_shape[0], out_channels=32, kernel_size=3)
        self.pool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3)
        self.pool2 = nn.MaxPool2d(kernel_size=2)
        self.conv3 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3)
        self.pool3 = nn.MaxPool2d(kernel_size=2)
        self.fc1 = nn.Linear(in_features=128 * 12 * 12, out_features=512)
        self.fc2 = nn.Linear(in_features=512, out_features=num_classes)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = self.pool3(x)
        x = x.view(-1, 128 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# Set the hyperparameters
input_shape = (3, 32, 32) # Input shape of each image
num_classes = 10 # Number of output classes
learning_rate = 0.001
batch_size = 32
num_epochs = 100

# Define the PyTorch neural network classifier
Two_CNN = NeuralNetClassifier(
    CNN2D(input_shape, num_classes),
    criterion=nn.CrossEntropyLoss,
    optimizer=optim.Adam,
    lr=learning_rate,
    batch_size=batch_size,
    max_epochs=num_epochs,
    device='cuda' if torch.cuda.is_available() else 'cpu',
    callbacks=[
        ('early_stop', EarlyStopping(monitor='valid_loss', patience=5))
    ]
)

# %% [markdown]
# <h3>DataFrameTransformer</h3>

# %%
#Import SKlearn Pipeline
from sklearn.pipeline import Pipeline

# %%
#Dataframe Transformer

from skorch.helper import DataFrameTransformer
nn_pipe = Pipeline(
    [
        ("transform", DataFrameTransformer()),
        ("net", net),
        ("tabnet", neural),
        ("One_CNN", One_CNN),
        ("Two_CNN", Two_CNN)
    ]
)

# %%
print(nn_pipe)
# Out:
# Pipeline(steps=[('transform', DataFrameTransformer()),
#                 ('net',
#                  <class 'skorch.classifier.NeuralNetClassifier'>[uninitialized](
#   module=<class '__main__.Net'>,
# )),
#                 ('tabnet',
#                  <class 'skorch.classifier.NeuralNetClassifier'>[uninitialized](
#   module=TabNetClassifier(n_d=8, n_a=8, n_steps=3, gamma=1.3, cat_idxs=[], cat_dims=[], cat_emb_dim=1, n_independent=2, n_shared=2, eps...
#     (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (fc1): Linear(in_features=18432, out_features=512, bias=True)
#     (fc2): Linear(in_features=512, out_features=10, bias=True)
#     (dropout): Dropout(p=0.5, inplace=False)
#   ),
# ))])

# %%
#Take a smaller sample to save memory
sample = combined_df.sample(n=50)

# %%
from pycaret.classification import *
target = "hf_type"
clf1 = setup(data = sample, 
            target = target,
            train_size = 0.8,
            fold = 5,
            session_id = 123,
            log_experiment = True, 
            experiment_name = 'electrical_grid_1', 
            )
# Out:
# <style type="text/css">
# #T_ce558_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ce558">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce558_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ce558_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce558_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce558_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ce558_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce558_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ce558_row1_col1" class="data row1 col1" >hf_type</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce558_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ce558_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce558_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ce558_row3_col1" class="data row3 col1" >(50, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce558_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ce558_row4_col1" class="data row4 col1" >(50, 96)</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce558_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ce558_row5_col1" class="data row5 col1" >(40, 96)</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce558_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ce558_row6_col1" class="data row6 col1" >(10, 96)</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce558_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_ce558_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce558_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_ce558_row8_col1" class="data row8 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ce558_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_ce558_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ce558_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_ce558_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ce558_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_ce558_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ce558_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_ce558_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ce558_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_ce558_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ce558_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_ce558_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ce558_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_ce558_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ce558_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_ce558_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ce558_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_ce558_row17_col1" class="data row17 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ce558_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_ce558_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ce558_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_ce558_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ce558_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_ce558_row20_col1" class="data row20 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ce558_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_ce558_row21_col1" class="data row21 col1" >electrical_grid_1</td>
#     </tr>
#     <tr>
#       <th id="T_ce558_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ce558_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_ce558_row22_col1" class="data row22 col1" >69ff</td>
#     </tr>
#   </tbody>
# </table>
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              10:11:38
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET WARNING: Experiment was interrupted by user while waiting for the initial data logger to be flushed.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5
# COMET INFO:     Accuracy : 0.725
# COMET INFO:     F1       : 0.6104
# COMET INFO:     Kappa    : 0.0
# COMET INFO:     MCC      : 0.0
# COMET INFO:     Prec.    : 0.5281
# COMET INFO:     Recall   : 0.725
# COMET INFO:     TT       : 0.306
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : c6930a9da4224daab847721b824fa69d
# COMET INFO:     Run Time           : 1.97
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 037d3d72
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     boosting_type     : gbdt
# COMET INFO:     class_weight      : 1
# COMET INFO:     colsample_bytree  : 1.0
# COMET INFO:     importance_type   : split
# COMET INFO:     learning_rate     : 0.1
# COMET INFO:     max_depth         : -1
# COMET INFO:     min_child_samples : 20
# COMET INFO:     min_child_weight  : 0.001
# COMET INFO:     min_split_gain    : 0.0
# COMET INFO:     n_estimators      : 100
# COMET INFO:     n_jobs            : -1
# COMET INFO:     num_leaves        : 31
# COMET INFO:     objective         : 1
# COMET INFO:     random_state      : 123
# COMET INFO:     reg_alpha         : 0.0
# COMET INFO:     reg_lambda        : 0.0
# COMET INFO:     silent            : warn
# COMET INFO:     subsample         : 1.0
# COMET INFO:     subsample_for_bin : 200000
# COMET INFO:     subsample_freq    : 0
# COMET INFO:   Uploads:
# COMET INFO:     asset               : 7 (34.89 KB)
# COMET INFO:     environment details : 1
# COMET INFO:     filename            : 1
# COMET INFO:     git metadata        : 1
# COMET INFO:     installed packages  : 1
# COMET INFO:     notebook            : 1
# COMET INFO:     os packages         : 1
# COMET INFO:     source_code         : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/229cd9605c454d1e85a7e4b28b364142.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.

# %%
models = [best, nn_pipe]

# %%
#Compare Best NN Model
best_nn = compare_models(include=[nn_pipe, best], sort="F1")
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              09:20:47
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5
# COMET INFO:     Accuracy : 0.725
# COMET INFO:     F1       : 0.6104
# COMET INFO:     Kappa    : 0.0
# COMET INFO:     MCC      : 0.0
# COMET INFO:     Prec.    : 0.5281
# COMET INFO:     Recall   : 0.725
# COMET INFO:     TT       : 0.24
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 9f3ef816e7a04b3b8dd2646c38a7ff2b
# COMET INFO:     Run Time           : 1.6
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 79e255a0
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     boosting_type     : gbdt
# COMET INFO:     class_weight      : 1
# COMET INFO:     colsample_bytree  : 1.0
# COMET INFO:     importance_type   : split
# COMET INFO:     learning_rate     : 0.1
# COMET INFO:     max_depth         : -1
# COMET INFO:     min_child_samples : 20
# COMET INFO:     min_child_weight  : 0.001
# COMET INFO:     min_split_gain    : 0.0
# COMET INFO:     n_estimators      : 100
# COMET INFO:     n_jobs            : -1
# COMET INFO:     num_leaves        : 31
# COMET INFO:     objective         : 1
# COMET INFO:     random_state      : 123
# COMET INFO:     reg_alpha         : 0.0
# COMET INFO:     reg_lambda        : 0.0
# COMET INFO:     silent            : warn
# COMET INFO:     subsample         : 1.0
# COMET INFO:     subsample_for_bin : 200000
# COMET INFO:     subsample_freq    : 0
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 7 (34.88 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/26e6c239257b4471a68cc06b8c734487.zip

# %%
# !pip install -U skorch
# Out:
# WARNING: Ignoring invalid distribution -andas (/home/brandon/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: skorch in /home/brandon/anaconda3/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.13.3 in /home/brandon/anaconda3/lib/python3.9/site-packages (from skorch) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/brandon/anaconda3/lib/python3.9/site-packages (from skorch) (1.2.2)
# Requirement already satisfied: scipy>=1.1.0 in /home/brandon/anaconda3/lib/python3.9/site-packages (from skorch) (1.9.1)
# Requirement already satisfied: tabulate>=0.7.7 in /home/brandon/anaconda3/lib/python3.9/site-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /home/brandon/anaconda3/lib/python3.9/site-packages (from skorch) (4.64.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/brandon/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.0->skorch) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/brandon/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22.0->skorch) (3.1.0)
# WARNING: Ignoring invalid distribution -andas (/home/brandon/anaconda3/lib/python3.9/site-packages)

# %%
#!pip install pytorch_tabular --quiet
#
#from skorch.classifier import NeuralNetClassifier
#from sklearn.pipeline import Pipeline
#from skorch.callbacks import EarlyStopping
#from pytorch_tabular import TabularModel
#from pytorch_tabular.models import TabNetModelConfig
#from pytorch_tabular.config import DataConfig, OptimizerConfig, TrainerConfig
#from skorch import NeuralNetClassifier
#
#
#
## load data
#data = sample
#
## define pipeline
#numeric_features = data.select_dtypes(include=['float64', 'int64']).columns.tolist()
#
#preprocessor = Pipeline(steps=[('transform', DataFrameTransformer(float_dtype='float32',
#                                                                  int_dtype='int32',
#                                                                  treat_int_as_categorical=False))])
#
#net = NeuralNetClassifier(module=nn_pipe,
#                          module__input_units=len(numeric_features),
#                          module__output_units=2,
#                          max_epochs=10,
#                          lr=0.1,
#                          optimizer=torch.optim.Adam,
#                          criterion=torch.nn.CrossEntropyLoss,
#                          device='cuda' if torch.cuda.is_available() else 'cpu')
#
#pipeline = Pipeline(steps=[('preprocessor', preprocessor),
#                           ('net', net)])
#
## create model using create_model()
#model = create_model(pipeline, verbose=False)
#
## evaluate model
#evaluate_model(model)
#
#
#

# %%
sample.columns
# Out:
# Index(['age', 'sex', 'weight', 'height', 'subject_id', 'study_id', 'hf_type',
#        'sample_rate_scgk', 'sample_rate_rsp', 'nrg_lin_scgk_mean',
#        'nrg_lin_scgk_std', 'nrg_lin_scgk_median', 'nrg_lin_scgk_min',
#        'nrg_lin_scgk_max', 'nrg_lin_scgk_skew', 'nrg_lin_scgk_kurt',
#        'nrg_lin_scgk_rms', 'nrg_lin_scgk_zero_crossings',
#        'nrg_lin_scgk_wavelet_mean', 'nrg_lin_scgk_wavelet_std',
#        'nrg_lin_scgk_wavelet_energy', 'nrg_rot_scgk_mean', 'nrg_rot_scgk_std',
#        'nrg_rot_scgk_median', 'nrg_rot_scgk_min', 'nrg_rot_scgk_max',
#        'nrg_rot_scgk_skew', 'nrg_rot_scgk_kurt', 'nrg_rot_scgk_rms',
#        'nrg_rot_scgk_zero_crossings', 'nrg_rot_scgk_wavelet_mean',
#        'nrg_rot_scgk_wavelet_std', 'nrg_rot_scgk_wavelet_energy',
#        'pwr_lin_scgk_mean', 'pwr_lin_scgk_std', 'pwr_lin_scgk_median',
#        'pwr_lin_scgk_min', 'pwr_lin_scgk_max', 'pwr_lin_scgk_skew',
#        'pwr_lin_scgk_kurt', 'pwr_lin_scgk_rms', 'pwr_lin_scgk_zero_crossings',
#        'pwr_lin_scgk_wavelet_mean', 'pwr_lin_scgk_wavelet_std',
#        'pwr_lin_scgk_wavelet_energy', 'pwr_rot_scgk_mean', 'pwr_rot_scgk_std',
#        'pwr_rot_scgk_median', 'pwr_rot_scgk_min', 'pwr_rot_scgk_max',
#        'pwr_rot_scgk_skew', 'pwr_rot_scgk_kurt', 'pwr_rot_scgk_rms',
#        'pwr_rot_scgk_zero_crossings', 'pwr_rot_scgk_wavelet_mean',
#        'pwr_rot_scgk_wavelet_std', 'pwr_rot_scgk_wavelet_energy', 'rsp_mean',
#        'rsp_std', 'rsp_median', 'rsp_min', 'rsp_max', 'rsp_skew', 'rsp_kurt',
#        'rsp_rms', 'rsp_zero_crossings', 'rsp_wavelet_mean', 'rsp_wavelet_std',
#        'rsp_wavelet_energy', 'nrg_lin_mean_freq', 'nrg_lin_median_freq',
#        'nrg_lin_peak_freq', 'nrg_lin_spectral_entropy', 'nrg_rot_mean_freq',
#        'nrg_rot_median_freq', 'nrg_rot_peak_freq', 'nrg_rot_spectral_entropy',
#        'pwr_lin_mean_freq', 'pwr_lin_median_freq', 'pwr_lin_peak_freq',
#        'pwr_lin_spectral_entropy', 'pwr_rot_mean_freq', 'pwr_rot_median_freq',
#        'pwr_rot_peak_freq', 'pwr_rot_spectral_entropy', 'rsp_mean_freq',
#        'rsp_median_freq', 'rsp_peak_freq', 'rsp_spectral_entropy'],
#       dtype='object')

# %%
sample.head()
# Out:
#                                                      age     sex  weight  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD         69.0  Female    68.0
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s     29.0    Male    71.4
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD         45.0    Male    95.0
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD         70.0  Female    70.0
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...  65.0    Male    74.0
#
#                                                     height subject_id  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD           1.60         MC
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s       1.74          U
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD           1.75         TQ
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD           1.62         MD
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...    1.73         YE
#
#                                                            study_id  hf_type  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                HAP-Test        0
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s               K-ICB        0
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                HAP-Test        0
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                HAP-Test        0
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...  KINO-HFrEF-Brug        0
#
#                                                     sample_rate_scgk  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                      250
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s                  200
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                      250
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                      250
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...               200
#
#                                                     sample_rate_rsp  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                     250
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s                 200
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                     250
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                     250
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...              200
#
#                                                     nrg_lin_scgk_mean  ...  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD              2.914829e-07  ...
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s          8.597045e-08  ...
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD              5.278546e-07  ...
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD              2.938018e-07  ...
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...       3.619068e-08  ...
#
#                                                     pwr_lin_peak_freq  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                  0.000098
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s              0.135128
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                  0.000196
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                  0.000098
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...           0.045080
#
#                                                     pwr_lin_spectral_entropy  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                         6.723479
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s                     6.807209
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                         6.739383
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                         6.717198
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...                  6.474318
#
#                                                     pwr_rot_mean_freq  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                  0.250000
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s              0.250000
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                  0.250000
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                  0.250000
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...           0.249979
#
#                                                     pwr_rot_median_freq  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                    0.250000
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s                0.250000
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                    0.250000
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                    0.250000
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...             0.249979
#
#                                                     pwr_rot_peak_freq  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                  0.000098
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s              0.135128
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                  0.000196
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                  0.000098
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...           0.249979
#
#                                                     pwr_rot_spectral_entropy  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                         7.227367
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s                     6.852696
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                         7.145468
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                         7.142014
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...                  7.269163
#
#                                                     rsp_mean_freq  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD              0.250000
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s          0.250000
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD              0.250000
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD              0.250000
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...       0.249979
#
#                                                     rsp_median_freq  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                0.250000
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s            0.250000
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                0.250000
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                0.250000
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...         0.249979
#
#                                                     rsp_peak_freq  \
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD              0.000978
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s          0.001501
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD              0.000392
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD              0.000979
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...       0.001750
#
#                                                     rsp_spectral_entropy
# HAP-Test_MC_0_20220214-123731_nWY689kvoUKSD                     1.206507
# K-ICB_U_BDC10_20190910-092528_aBOB0aOW8tERH2_6s                 2.238054
# HAP-Test_TQ_1_20220214-090448_nWY6qKMdlhKSD                     2.844196
# HAP-Test_MD_0_20220209-095223_nWYPWgGnpiKSD                     2.397772
# KINO-HFrEF-Brug_YE_kinoV1_20181214-140454_LXG25...              2.525728
#
# [5 rows x 89 columns]

# %%
best = compare_models(n_select=3)
best_model_nn = compare_models(include=[nn_pipe, best], sort="F1")
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              09:53:58
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# Empty DataFrame
# Columns: [Model, Accuracy, AUC, Recall, Prec., F1, Kappa, MCC, TT (Sec)]
# Index: []
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5
# COMET INFO:     Accuracy : 0.725
# COMET INFO:     F1       : 0.6104
# COMET INFO:     Kappa    : 0.0
# COMET INFO:     MCC      : 0.0
# COMET INFO:     Prec.    : 0.5281
# COMET INFO:     Recall   : 0.725
# COMET INFO:     TT       : 0.24
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 9d67616bffac47fbab1cd04e99fa9625
# COMET INFO:     Run Time           : 1.58
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : a6e5f689
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     boosting_type     : gbdt
# COMET INFO:     class_weight      : 1
# COMET INFO:     colsample_bytree  : 1.0
# COMET INFO:     importance_type   : split
# COMET INFO:     learning_rate     : 0.1
# COMET INFO:     max_depth         : -1
# COMET INFO:     min_child_samples : 20
# COMET INFO:     min_child_weight  : 0.001
# COMET INFO:     min_split_gain    : 0.0
# COMET INFO:     n_estimators      : 100
# COMET INFO:     n_jobs            : -1
# COMET INFO:     num_leaves        : 31
# COMET INFO:     objective         : 1
# COMET INFO:     random_state      : 123
# COMET INFO:     reg_alpha         : 0.0
# COMET INFO:     reg_lambda        : 0.0
# COMET INFO:     silent            : warn
# COMET INFO:     subsample         : 1.0
# COMET INFO:     subsample_for_bin : 200000
# COMET INFO:     subsample_freq    : 0
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 7 (34.89 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/3c377bdc1d804d5aabf5a67f7b94b14c.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5
# COMET INFO:     Accuracy : 0.725
# COMET INFO:     F1       : 0.6104
# COMET INFO:     Kappa    : 0.0
# COMET INFO:     MCC      : 0.0
# COMET INFO:     Prec.    : 0.5281
# COMET INFO:     Recall   : 0.725
# COMET INFO:     TT       : 0.138
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 873b33e4b7ba46359f094d1e32f1a59d
# COMET INFO:     Run Time           : 1.09
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : fa672352
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     constant     : 1
# COMET INFO:     random_state : 123
# COMET INFO:     strategy     : prior
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 7 (16.48 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/b7880ae1035a4d8d9c6f8067fb79599f.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5539
# COMET INFO:     Accuracy : 0.7
# COMET INFO:     F1       : 0.6069
# COMET INFO:     Kappa    : 0.0154
# COMET INFO:     MCC      : 0.016
# COMET INFO:     Prec.    : 0.5406
# COMET INFO:     Recall   : 0.7
# COMET INFO:     TT       : 0.462
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : f9695cf154b9446ab3d7704c386a2ae4
# COMET INFO:     Run Time           : 2.71
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : ed73f0e6
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     algorithm     : auto
# COMET INFO:     leaf_size     : 30
# COMET INFO:     metric        : minkowski
# COMET INFO:     metric_params : 1
# COMET INFO:     n_jobs        : -1
# COMET INFO:     n_neighbors   : 5
# COMET INFO:     p             : 2
# COMET INFO:     weights       : uniform
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 7 (48.63 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/64082f3074d444b7a66b74f70683b75e.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.6985
# COMET INFO:     Accuracy : 0.7
# COMET INFO:     F1       : 0.5973
# COMET INFO:     Kappa    : -0.0286
# COMET INFO:     MCC      : -0.0314
# COMET INFO:     Prec.    : 0.5228
# COMET INFO:     Recall   : 0.7
# COMET INFO:     TT       : 0.23
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 0b90917184eb46029c29c6911187852b
# COMET INFO:     Run Time           : 1.55
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : c9e7a411
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     bootstrap                : True
# COMET INFO:     ccp_alpha                : 0.0
# COMET INFO:     class_weight             : 1
# COMET INFO:     criterion                : gini
# COMET INFO:     max_depth                : 1
# COMET INFO:     max_features             : sqrt
# COMET INFO:     max_leaf_nodes           : 1
# COMET INFO:     max_samples              : 1
# COMET INFO:     min_impurity_decrease    : 0.0
# COMET INFO:     min_samples_leaf         : 1
# COMET INFO:     min_samples_split        : 2
# COMET INFO:     min_weight_fraction_leaf : 0.0
# COMET INFO:     n_estimators             : 100
# COMET INFO:     n_jobs                   : -1
# COMET INFO:     oob_score                : False
# COMET INFO:     random_state             : 123
# COMET INFO:     verbose                  : 0
# COMET INFO:     warm_start               : False
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (16.13 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/48b9788a1cf646d9b9458d6f50294145.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.6583
# COMET INFO:     Accuracy : 0.7
# COMET INFO:     F1       : 0.5973
# COMET INFO:     Kappa    : -0.0286
# COMET INFO:     MCC      : -0.0314
# COMET INFO:     Prec.    : 0.5228
# COMET INFO:     Recall   : 0.7
# COMET INFO:     TT       : 0.232
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 0719d00e67b1475b80b9f8333c0db5ce
# COMET INFO:     Run Time           : 1.59
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 1d67a315
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.58 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/3ecd0b3442ef45e59973c9bfb684b6c2.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5527
# COMET INFO:     Accuracy : 0.675
# COMET INFO:     F1       : 0.6042
# COMET INFO:     Kappa    : 0.0372
# COMET INFO:     MCC      : 0.0443
# COMET INFO:     Prec.    : 0.5482
# COMET INFO:     Recall   : 0.675
# COMET INFO:     TT       : 0.12
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : b3774bb52e4743d883fb00ea230bdbcc
# COMET INFO:     Run Time           : 1.0
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 98733a1e
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     algorithm      : SAMME.R
# COMET INFO:     base_estimator : deprecated
# COMET INFO:     estimator      : 1
# COMET INFO:     learning_rate  : 1.0
# COMET INFO:     n_estimators   : 50
# COMET INFO:     random_state   : 123
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.67 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/760539e7a0434980814fc647bec9818c.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.6991
# COMET INFO:     Accuracy : 0.675
# COMET INFO:     F1       : 0.6449
# COMET INFO:     Kappa    : 0.2153
# COMET INFO:     MCC      : 0.231
# COMET INFO:     Prec.    : 0.6598
# COMET INFO:     Recall   : 0.675
# COMET INFO:     TT       : 0.168
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : d3b764a7be564f4eac7a4995ffadf907
# COMET INFO:     Run Time           : 1.24
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 2a5ebafd
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     bootstrap                : False
# COMET INFO:     ccp_alpha                : 0.0
# COMET INFO:     class_weight             : 1
# COMET INFO:     criterion                : gini
# COMET INFO:     max_depth                : 1
# COMET INFO:     max_features             : sqrt
# COMET INFO:     max_leaf_nodes           : 1
# COMET INFO:     max_samples              : 1
# COMET INFO:     min_impurity_decrease    : 0.0
# COMET INFO:     min_samples_leaf         : 1
# COMET INFO:     min_samples_split        : 2
# COMET INFO:     min_weight_fraction_leaf : 0.0
# COMET INFO:     n_estimators             : 100
# COMET INFO:     n_jobs                   : -1
# COMET INFO:     oob_score                : False
# COMET INFO:     random_state             : 123
# COMET INFO:     verbose                  : 0
# COMET INFO:     warm_start               : False
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (16.13 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/a96e3f9fd7c540d1967c0a7fe29d7b1b.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.6155
# COMET INFO:     Accuracy : 0.675
# COMET INFO:     F1       : 0.6352
# COMET INFO:     Kappa    : 0.1856
# COMET INFO:     MCC      : 0.1938
# COMET INFO:     Prec.    : 0.615
# COMET INFO:     Recall   : 0.675
# COMET INFO:     TT       : 0.114
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 5681991aa9f14742bd93ce682efaf2a7
# COMET INFO:     Run Time           : 0.97
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 240d2b6e
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     base_score              : 1
# COMET INFO:     booster                 : gbtree
# COMET INFO:     colsample_bylevel       : 1
# COMET INFO:     colsample_bynode        : 1
# COMET INFO:     colsample_bytree        : 1
# COMET INFO:     enable_categorical      : False
# COMET INFO:     gamma                   : 1
# COMET INFO:     gpu_id                  : 1
# COMET INFO:     importance_type         : 1
# COMET INFO:     interaction_constraints : 1
# COMET INFO:     learning_rate           : 1
# COMET INFO:     max_delta_step          : 1
# COMET INFO:     max_depth               : 1
# COMET INFO:     min_child_weight        : 1
# COMET INFO:     missing                 : nan
# COMET INFO:     monotone_constraints    : 1
# COMET INFO:     n_estimators            : 100
# COMET INFO:     n_jobs                  : -1
# COMET INFO:     num_parallel_tree       : 1
# COMET INFO:     objective               : binary:logistic
# COMET INFO:     predictor               : 1
# COMET INFO:     random_state            : 123
# COMET INFO:     reg_alpha               : 1
# COMET INFO:     reg_lambda              : 1
# COMET INFO:     scale_pos_weight        : 1
# COMET INFO:     subsample               : 1
# COMET INFO:     tree_method             : auto
# COMET INFO:     use_label_encoder       : True
# COMET INFO:     validate_parameters     : 1
# COMET INFO:     verbosity               : 0
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (16.05 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/dc6bf4d85203491588d79f3089d7123e.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.0
# COMET INFO:     Accuracy : 0.65
# COMET INFO:     F1       : 0.5857
# COMET INFO:     Kappa    : -0.0198
# COMET INFO:     MCC      : -0.0207
# COMET INFO:     Prec.    : 0.5408
# COMET INFO:     Recall   : 0.65
# COMET INFO:     TT       : 0.126
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 8a2a1dc9f7424909bcc9d9e798b121e1
# COMET INFO:     Run Time           : 1.04
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 0b879973
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     alpha               : 0.0001
# COMET INFO:     average             : False
# COMET INFO:     class_weight        : 1
# COMET INFO:     early_stopping      : False
# COMET INFO:     epsilon             : 0.1
# COMET INFO:     eta                 : 0.001
# COMET INFO:     fit_intercept       : True
# COMET INFO:     l_ratio             : 0.15
# COMET INFO:     learning_rate       : optimal
# COMET INFO:     loss                : hinge
# COMET INFO:     max_iter            : 1000
# COMET INFO:     n_iter_no_change    : 5
# COMET INFO:     n_jobs              : -1
# COMET INFO:     penalty             : l2
# COMET INFO:     power_t             : 0.5
# COMET INFO:     random_state        : 123
# COMET INFO:     shuffle             : True
# COMET INFO:     tol                 : 0.001
# COMET INFO:     validation_fraction : 0.1
# COMET INFO:     verbose             : 0
# COMET INFO:     warm_start          : False
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.90 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/3c5451e8f12e468fb898b7825b762316.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.4929
# COMET INFO:     Accuracy : 0.65
# COMET INFO:     F1       : 0.5805
# COMET INFO:     Kappa    : -0.0418
# COMET INFO:     MCC      : -0.0469
# COMET INFO:     Prec.    : 0.5299
# COMET INFO:     Recall   : 0.65
# COMET INFO:     TT       : 0.13
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : e65396ce5f2e4e75a6060b69d7853e1e
# COMET INFO:     Run Time           : 1.08
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 7fb98ea7
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     priors           : 1
# COMET INFO:     reg_param        : 0.0
# COMET INFO:     store_covariance : False
# COMET INFO:     tol              : 0.0001
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.62 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/7d29a3f0da044f728751a6f5bda6dd8e.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.7155
# COMET INFO:     Accuracy : 0.65
# COMET INFO:     F1       : 0.6091
# COMET INFO:     Kappa    : 0.1713
# COMET INFO:     MCC      : 0.1984
# COMET INFO:     Prec.    : 0.5961
# COMET INFO:     Recall   : 0.65
# COMET INFO:     TT       : 0.094
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 1e6171c17cc248ccb877641a2b96e8c6
# COMET INFO:     Run Time           : 0.92
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : c5e37f56
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     covariance_estimator : 1
# COMET INFO:     n_components         : 1
# COMET INFO:     priors               : 1
# COMET INFO:     shrinkage            : 1
# COMET INFO:     solver               : svd
# COMET INFO:     store_covariance     : False
# COMET INFO:     tol                  : 0.0001
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.67 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/fd0ddcb19e814b99b87abfb2e274c901.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.5518
# COMET INFO:     Accuracy : 0.6
# COMET INFO:     F1       : 0.5667
# COMET INFO:     Kappa    : 0.0943
# COMET INFO:     MCC      : 0.099
# COMET INFO:     Prec.    : 0.5658
# COMET INFO:     Recall   : 0.6
# COMET INFO:     TT       : 0.202
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 882c3040637d411081f1ce469f9eb006
# COMET INFO:     Run Time           : 1.41
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 483d5a43
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     ccp_alpha                : 0.0
# COMET INFO:     criterion                : friedman_mse
# COMET INFO:     init                     : 1
# COMET INFO:     learning_rate            : 0.1
# COMET INFO:     loss                     : log_loss
# COMET INFO:     max_depth                : 3
# COMET INFO:     max_features             : 1
# COMET INFO:     max_leaf_nodes           : 1
# COMET INFO:     min_impurity_decrease    : 0.0
# COMET INFO:     min_samples_leaf         : 1
# COMET INFO:     min_samples_split        : 2
# COMET INFO:     min_weight_fraction_leaf : 0.0
# COMET INFO:     n_estimators             : 100
# COMET INFO:     n_iter_no_change         : 1
# COMET INFO:     random_state             : 123
# COMET INFO:     subsample                : 1.0
# COMET INFO:     tol                      : 0.0001
# COMET INFO:     validation_fraction      : 0.1
# COMET INFO:     verbose                  : 0
# COMET INFO:     warm_start               : False
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.94 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# ...
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     C                 : 1.0
# COMET INFO:     class_weight      : 1
# COMET INFO:     dual              : False
# COMET INFO:     fit_intercept     : True
# COMET INFO:     intercept_scaling : 1
# COMET INFO:     l_ratio           : 1
# COMET INFO:     max_iter          : 1000
# COMET INFO:     multi_class       : auto
# COMET INFO:     n_jobs            : 1
# COMET INFO:     penalty           : l2
# COMET INFO:     random_state      : 123
# COMET INFO:     solver            : lbfgs
# COMET INFO:     tol               : 0.0001
# COMET INFO:     verbose           : 0
# COMET INFO:     warm_start        : False
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.75 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/26dfe31203d24062b8ecb282e38ab235.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.6821
# COMET INFO:     Accuracy : 0.575
# COMET INFO:     F1       : 0.5645
# COMET INFO:     Kappa    : 0.0966
# COMET INFO:     MCC      : 0.1215
# COMET INFO:     Prec.    : 0.6333
# COMET INFO:     Recall   : 0.575
# COMET INFO:     TT       : 0.104
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 5c5069118393434cb40d0caee3c06732
# COMET INFO:     Run Time           : 0.88
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 03e94422
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     priors        : 1
# COMET INFO:     var_smoothing : 1e-09
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.56 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/353f635ddc0547f3909d5d2d0834964b.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.0
# COMET INFO:     Accuracy : 0.55
# COMET INFO:     F1       : 0.5312
# COMET INFO:     Kappa    : -0.033
# COMET INFO:     MCC      : -0.0209
# COMET INFO:     Prec.    : 0.5594
# COMET INFO:     Recall   : 0.55
# COMET INFO:     TT       : 0.132
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : 4fa7d4be871b4dd2ac43ee2570ac987b
# COMET INFO:     Run Time           : 1.07
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : f5381d30
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     alpha         : 1.0
# COMET INFO:     class_weight  : 1
# COMET INFO:     copy_X        : True
# COMET INFO:     fit_intercept : True
# COMET INFO:     max_iter      : 1
# COMET INFO:     positive      : False
# COMET INFO:     random_state  : 123
# COMET INFO:     solver        : auto
# COMET INFO:     tol           : 0.0001
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.66 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/9f105d1fc1c04a7f92e9dc25f2b620ce.zip
# COMET WARNING: MLFlow Nested Runs are not tracked in Comet.ml SDK.
# COMET INFO: No Comet API Key was found, creating an OfflineExperiment. Set up your API Key to get the full Comet experience https://www.comet.com/docs/python-sdk/advanced/#python-configuration
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Using '/home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs' path as offline directory. Pass 'offline_directory' parameter into constructor or set the 'COMET_OFFLINE_DIRECTORY' environment variable to manually choose where to store offline experiment archives.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml OfflineExperiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : [OfflineExperiment will get URL after upload]
# COMET INFO:   Metrics:
# COMET INFO:     AUC      : 0.4548
# COMET INFO:     Accuracy : 0.525
# COMET INFO:     F1       : 0.4938
# COMET INFO:     Kappa    : -0.0595
# COMET INFO:     MCC      : -0.0605
# COMET INFO:     Prec.    : 0.5113
# COMET INFO:     Recall   : 0.525
# COMET INFO:     TT       : 0.128
# COMET INFO:   Others:
# COMET INFO:     Created from       : MLFlow auto-logger
# COMET INFO:     Run ID             : cd65f1b7f3cd4291b442c6719ef4fdc4
# COMET INFO:     Run Time           : 1.06
# COMET INFO:     Source             : compare_models
# COMET INFO:     URI                : 483b25ce
# COMET INFO:     USI                : 69ff
# COMET INFO:     mlflow.parentRunId : bd09ce9813164038b826caa131bcd0dc
# COMET INFO:     offline_experiment : True
# COMET INFO:   Parameters:
# COMET INFO:     ccp_alpha                : 0.0
# COMET INFO:     class_weight             : 1
# COMET INFO:     criterion                : gini
# COMET INFO:     max_depth                : 1
# COMET INFO:     max_features             : 1
# COMET INFO:     max_leaf_nodes           : 1
# COMET INFO:     min_impurity_decrease    : 0.0
# COMET INFO:     min_samples_leaf         : 1
# COMET INFO:     min_samples_split        : 2
# COMET INFO:     min_weight_fraction_leaf : 0.0
# COMET INFO:     random_state             : 123
# COMET INFO:     splitter                 : best
# COMET INFO:   Uploads:
# COMET INFO:     asset                        : 6 (15.78 KB)
# COMET INFO:     conda-environment-definition : 1
# COMET INFO:     conda-info                   : 1
# COMET INFO:     conda-specification          : 1
# COMET INFO:     environment details          : 1
# COMET INFO:     filename                     : 1
# COMET INFO:     git metadata                 : 1
# COMET INFO:     installed packages           : 1
# COMET INFO:     notebook                     : 1
# COMET INFO:     os packages                  : 1
# COMET INFO:     source_code                  : 1
# COMET INFO:
# COMET WARNING: Experiment Name is generated at upload time for Offline Experiments unless set explicitly with Experiment.set_name
# COMET WARNING: Comet has disabled auto-logging functionality as it has been imported after the following ML modules: sklearn, torch, tensorflow, keras, prophet, tensorboard. Metrics and hyperparameters can still be logged using Experiment.log_metrics() and Experiment.log_parameters()
# COMET INFO: Starting saving the offline archive
# COMET INFO: To upload this offline experiment, run:
#     comet upload /home/brandon/Omdena/Omdena HeartKinetics/HeartKinetics - Project/.cometml-runs/252a88f3a1024300b6d0d8ae3dc9116d.zip
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_45280/629276701.py in <cell line: 2>()
#       1 best = compare_models(n_select=3)
# ----> 2 best_model_nn = compare_models(include=[nn_pipe, best], sort="F1")
#
# ~/anaconda3/lib/python3.9/site-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     962                 if globals_d[name] is None:
#     963                     raise ValueError(message)
# --> 964             return func(*args, **kwargs)
#     965
#     966         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pycaret/classification/functional.py in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#     816     """
#     817
# --> 818     return _CURRENT_EXPERIMENT.compare_models(
#     819         include=include,
#     820         exclude=exclude,
#
# ~/anaconda3/lib/python3.9/site-packages/pycaret/classification/oop.py in compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, engine, verbose, parallel)
#    1183
#    1184         try:
# -> 1185             return_values = super().compare_models(
#    1186                 include=include,
#    1187                 exclude=exclude,
#
# ~/anaconda3/lib/python3.9/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py in compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     556                         )
#     557                 elif not hasattr(i, "fit"):
# --> 558                     raise ValueError(
#     559                         f"Estimator {i} does not have the required fit() method."
#     560                     )
#
# ValueError: Estimator [LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0), DummyClassifier(constant=None, random_state=123, strategy='prior'), KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform')] does not have the required fit() method.

# %%
#test models

if best_model_nn:
    prediction = predict_model(best_model_nn[0], data=sample)
else:
    print("No models found that include both nn_pipe and best.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_45280/933222394.py in <cell line: 3>()
#       1 #test models
#       2
# ----> 3 if best_model_nn:
#       4     prediction = predict_model(best_model_nn[0], data=sample)
#       5 else:
#
# NameError: name 'best_model_nn' is not defined

# %%
#Plot AUC
plot_model(best_model_nn, plot = 'auc')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_45280/245159102.py in <cell line: 2>()
#       1 #Plot AUC
# ----> 2 plot_model(best_model_nn, plot = 'auc')
#
# NameError: name 'best_model_nn' is not defined

# %%
#Plot Confusion Matrix
plot_model(best_model_nn, plot = 'confusion_matrix')

# %%
#Plot Feature Importance
plot_model(best_model_nn, plot = 'feature')

# %%
#Plot Precision Recall Curve
plot_model(best_model_nn, plot = 'pr')

# %%
#Plot Validation Curve
plot_model(best_model_nn, plot = 'vc')

# %%
#Plot Classification Report
plot_model(best_model_nn, plot = 'class_report')

# %%
#Plot Dimensions
plot_model(best_model_nn, plot = 'dimension')

# %%
# !mlflow ui
